# %% [markdown]
# # PETITE Tutorial
# Authors: Nikita Blinov (York U.), Patrick J. Fox (Fermilab), Kevin J. Kelly (Texas A&M), Pedro A. N. Machado (Fermilab), and Ryan Plestid (Caltech)
#
# PETITE is a simple, lightweight, toy Monte Carlo that generates realistic electromagnetic showers, with or without new physics.
# Currently, dark photons with pure vector couplins are incorporated in PETITE.
#
# PETITE includes explicit simulation of (we denote nuclei by their electric charge $Z$)
#
# * Bremsstrahlung  $e^\pm Z \rightarrow e^\pm \gamma Z$.
# * Pair production $\gamma Z \rightarrow e^+ e^- Z$.
# * Compton scattering $\gamma e^- \rightarrow  \gamma e^-$
# * Pair-annihilation $e^+ e^- \rightarrow \gamma\gamma$
# * Moller Scattering $e^- e^- \rightarrow e^- e^-$
# * Bhabha Scattering $e^+ e^- \rightarrow e^+ e^-$
#
# and implicit simulation of
#
# * Multiple Coulomb scattering
# * Energy loss by ionization
#
# ${\bf Dependencies}$: numpy, vegas, pickle, cProfile, tqdm, scipy
#
# ${\bf Version~ requirements}$: numpy 1.24  ,  python3.xx with xx$\geq$9.
#
# ${\bf Directory~structure}$: This notebook assumes that within a PETITE home directory there is folder containing dictionaries, and that within that folder the following files exist
#
# * $\verb|<PETITE_home_dir>|$/$\verb|<dictionary_dir>|$/sm_xsec.pkl
# * $\verb|<PETITE_home_dir>|$/$\verb|<dictionary_dir>|$/sm_maps.pkl
#
# You can check versions with the code below and adjust if necessary.
#
# In this tutorial you will learn how to
# 1. Initialize PETITE
# 2. Generate a standard electromagnetic shower
# 3. Generate a shower with a dark photon
# 4. Analyze the accept/reject method used by PETITE, based on precomputed shower samples
# 5. Understand how to generate novel shower samples.

# %%
# Force reload (if changes have been made to the module)
# %load_ext autoreload
# %autoreload 2

# Initialization of the tutorial
from platform import python_version
print("Python version: ", python_version())

import numpy as np
print("Numpy version: ", np.__version__)

import os
current_path = os.getcwd()
PETITE_home_dir= current_path.split('examples')[0]

print("PETITE home directory:", PETITE_home_dir)
# folder where VEGAS dictionaries are stored
# dictionary_dir = "data/VEGAS_dictionaries/"
dictionary_dir = "data/"
# Out:
# Python version:  3.8.5
# Numpy version:  1.24.4
# PETITE home directory: /Users/taozhou/Documents/GitHub/PETITE/

# %% [markdown]
# ### Load in dependencies and set font styles

# %%
# import src
import sys
sys.path.append(PETITE_home_dir)
from src.shower import *
import pickle as pk
from matplotlib import pyplot as plt
from tqdm import tqdm
#from tqdm.notebook import tqdm

import matplotlib

from matplotlib.font_manager import FontProperties
from matplotlib.ticker import FixedLocator, MaxNLocator
import cProfile
profile = cProfile.Profile()
import pstats

font0 = FontProperties()
font = font0.copy()
font.set_size(24)
font.set_family('serif')
labelfont=font0.copy()
labelfont.set_size(20)
labelfont.set_weight('bold')
legfont=font0.copy()
legfont.set_size(18)
legfont.set_weight('bold')


def set_size(w,h, ax=None):
    """ Helper function to set figure size.
        Input:
            w, h: width, height in inches """
    if not ax: ax=plt.gca()
    l = ax.figure.subplotpars.left
    r = ax.figure.subplotpars.right
    t = ax.figure.subplotpars.top
    b = ax.figure.subplotpars.bottom
    figw = float(w)/(r-l)
    figh = float(h)/(t-b)
    ax.figure.set_size_inches(figw, figh)

# %% [markdown]
# ####  Outline
#
# - Generating standard model shower
# - Generating dark photon shower
# - Plotting acceptance
# - Plotting individual processes
# - Generating novel shower samples
# - Analyzing accept-reject method in PETITE

# %% [markdown]
# ## Shower production with PETITE
#
# The primary purpose of PETITE is to produce realistic electromagnetic showers with a lightweight, reasonably fast, python-native code base. We illustrate its performance below.
#
# We will shoot a 10 GeV particle incident on either lead or graphite. Particles are specified by their PDG codes (see e.g. https://pdg.lbl.gov/2007/reviews/montecarlorpp.pdf). Units in PETITE are GeV, meters, and radians.
#
# * ${\rm PDG}(e^\pm)=\pm11$
# * ${\rm PDG}(\gamma)~~=+22$

# %%
E0 = 12.057 # energy of incident particle in GeV

# Define incident electron, 10 GeV electron on z axis
#px, py, pz = 0, 0, np.sqrt(E0**2 - 0.000511**2)

px, py, pz = 2.3721, -0.645122, 11.8029
# dictionary with particle properties
# The crucial keys are 'PID' and 'ID', others are for efficient bookkeeping
# Neutral pion PID: 111
particle_dict = {'PID':111, 'ID':0, 'generation_number':0, 'generation_process':'Input', "stability":"short-lived"}
p0 = Particle([E0, px, py, pz], [0,0,0], particle_dict)

# %%
# Shower(directory, material, minimum_energy). 
# Create instances of Shower class for graphite and lead
#sGraphite = Shower(PETITE_home_dir+dictionary_dir, "graphite", 0.010)
#sLead = Shower(PETITE_home_dir+dictionary_dir, "lead", 0.010)
#sMolybdenum = Shower(PETITE_home_dir+dictionary_dir, "molybdenum", 0.010) 
sTungsten = Shower(PETITE_home_dir+dictionary_dir, "tungsten", min_energy=0.010, target_length=0.0000001)
# Generate standard shower for graphite and lead, let's turn on verbosity to see what's going on
#standard_shower_molybdenum = sMolybdenum.generate_shower(p0, VB=True)
#standard_shower_lead = sLead.generate_shower(p0, VB=True)
standard_shower_tungsten = sTungsten.generate_shower(p0, VB=True)
print(len(standard_shower_tungsten))
# Out:
# Starting shower, initial particle with ID Info
# {'PID': 111, 'ID': 0, 'parent_PID': 22, 'parent_ID': -1, 'generation_number': 0, 'generation_process': 'Input', 'weight': 1.0, 'mass': 0.14057, 'stability': 'short-lived'}
# Initial four-momenta:
# [12.057     2.3721   -0.645122 11.8029  ]
# 2839

# %% [markdown]
# The shower is now generated. The object standard_shower_graphite is a list of particles generated throughout the shower. We can look at some of their properties.

# %% [markdown]
# ## finite target length

# %%
# Let's look at different particles in the shower and their properties.
print('Total number of particles: ', len(standard_shower_tungsten))

photons = [p for p in standard_shower_tungsten if p.get_pid() == 22]
electrons = [p for p in standard_shower_tungsten if p.get_pid() == 11]
positrons = [p for p in standard_shower_tungsten if p.get_pid() == -11]
print('Number of (photons, electrons, positrons): ', len(photons), len(electrons), len(positrons))

# Let's look at the energy and angle spectra of all particles.
# Let's make these plots in log-log scale, all particles go in the same plot, energy goes in the left panel, while angle goes in the right panel.
bins_energy = np.logspace(-3, 4, 20)
bins_angle = np.logspace(-3, 0, 20) # radians
plt.figure(figsize=(12, 3))
plt.subplot(121)
plt.hist([p.get_p0()[0] for p in photons], bins=bins_energy, histtype='step', label='photons')
plt.hist([p.get_p0()[0] for p in electrons], bins=bins_energy, histtype='step', label='electrons')
plt.hist([p.get_p0()[0] for p in positrons], bins=bins_energy, histtype='step', label='positrons')
plt.xscale('log')
plt.yscale('log')
plt.xlabel('Energy (MeV)')
plt.ylabel('Number of particles')
plt.legend()
plt.subplot(122)
plt.hist([p.get_angle_to_z_0() for p in photons], bins=bins_angle, histtype='step', label='photons')
plt.hist([p.get_angle_to_z_0() for p in electrons], bins=bins_angle, histtype='step', label='electrons')
plt.hist([p.get_angle_to_z_0() for p in positrons], bins=bins_angle, histtype='step', label='positrons')
plt.xscale('log')
plt.yscale('log')
plt.xlabel('Angle to z-axis at production (rad)')
plt.ylabel('Number of particles')
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# Total number of particles:  2904
# Number of (photons, electrons, positrons):  529 1386 988

# %% [markdown]
# ## Infinite target

# %%
sTungsten_1000 = Shower(PETITE_home_dir+dictionary_dir, "tungsten", 0.010)
standard_shower_tungsten_1000 = sTungsten.generate_shower(p0, VB=True)
# Out:
# Starting shower, initial particle with ID Info
# {'PID': 111, 'ID': 0, 'parent_PID': 22, 'parent_ID': -1, 'generation_number': 0, 'generation_process': 'Input', 'weight': 1.0, 'mass': 0.14057, 'stability': 'short-lived'}
# Initial four-momenta:
# [12.057     2.3721   -0.645122 11.8029  ]

# %%
# Let's look at different particles in the shower and their properties.
print('Total number of particles: ', len(standard_shower_tungsten_1000))

photons = [p for p in standard_shower_tungsten_1000 if p.get_pid() == 22]
electrons = [p for p in standard_shower_tungsten_1000 if p.get_pid() == 11]
positrons = [p for p in standard_shower_tungsten_1000 if p.get_pid() == -11]
print('Number of (photons, electrons, positrons): ', len(photons), len(electrons), len(positrons))

# Let's look at the energy and angle spectra of all particles.
# Let's make these plots in log-log scale, all particles go in the same plot, energy goes in the left panel, while angle goes in the right panel.
bins_energy = np.logspace(-3, 4, 20)
bins_angle = np.logspace(-3, 0, 20) # radians
plt.figure(figsize=(12, 3))
plt.subplot(121)
plt.hist([p.get_p0()[0] for p in photons], bins=bins_energy, histtype='step', label='photons')
plt.hist([p.get_p0()[0] for p in electrons], bins=bins_energy, histtype='step', label='electrons')
plt.hist([p.get_p0()[0] for p in positrons], bins=bins_energy, histtype='step', label='positrons')
plt.xscale('log')
plt.yscale('log')
plt.xlabel('Energy (MeV)')
plt.ylabel('Number of particles')
plt.legend()
plt.subplot(122)
plt.hist([p.get_angle_to_z_0() for p in photons], bins=bins_angle, histtype='step', label='photons')
plt.hist([p.get_angle_to_z_0() for p in electrons], bins=bins_angle, histtype='step', label='electrons')
plt.hist([p.get_angle_to_z_0() for p in positrons], bins=bins_angle, histtype='step', label='positrons')
plt.xscale('log')
plt.yscale('log')
plt.xlabel('Angle to z-axis at production (rad)')
plt.ylabel('Number of particles')
plt.legend()
plt.tight_layout()
# Out:
# Total number of particles:  1855
# Number of (photons, electrons, positrons):  380 841 633

# %%
#Let's repeat the above but looking at the shower through lead instead of graphite:

print('Total number of particles: ', len(standard_shower_lead))
photons = [p for p in standard_shower_lead if p.get_pid() == 22]
electrons = [p for p in standard_shower_lead if p.get_pid() == 11]
positrons = [p for p in standard_shower_lead if p.get_pid() == -11]
print('Number of (photons, electrons, positrons): ', len(photons), len(electrons), len(positrons))
# Let's look at the energy and angle spectra of all particles.
# Let's make these plots in log-log scale, all particles go in the same plot, energy goes in the left panel, while angle goes in the right panel.
bins_energy = np.logspace(-3, 4, 20)
bins_angle = np.logspace(-3, 0, 20) # radians
plt.figure(figsize=(12, 3))
plt.subplot(121)
plt.hist([p.get_p0()[0] for p in photons], bins=bins_energy, histtype='step', label='photons')
plt.hist([p.get_p0()[0] for p in electrons], bins=bins_energy, histtype='step', label='electrons')
plt.hist([p.get_p0()[0] for p in positrons], bins=bins_energy, histtype='step', label='positrons')
plt.xscale('log')
plt.yscale('log')
plt.xlabel('Energy (MeV)')
plt.ylabel('Number of particles')
plt.legend()
plt.subplot(122)
plt.hist([p.get_angle_to_z_0() for p in photons], bins=bins_angle, histtype='step', label='photons')
plt.hist([p.get_angle_to_z_0() for p in electrons], bins=bins_angle, histtype='step', label='electrons')
plt.hist([p.get_angle_to_z_0() for p in positrons], bins=bins_angle, histtype='step', label='positrons')
plt.xscale('log')
plt.yscale('log')
plt.xlabel('Angle to z-axis at production (rad)')
plt.ylabel('Number of particles')
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# Total number of particles:  2912
# Number of (photons, electrons, positrons):  534 1381 996

# %%
# We can also see the shower display for both graphite and lead
# photon in green, electron in red, positron in blue
event_display(standard_shower_tungsten)
#event_display(standard_shower_tungsten_1000)
#event_display(standard_shower_lead)

# %% [markdown]
# Pretty neat, no? Notice the difference in the z-range, which is just a consequence of the smaller mean free path in lead.

# %% [markdown]
# ####  We looked at two shower objects, one with a graphite target and one with lead. Both track down to minimum energies of 10 MeV
#
# The minimum energy in the shower dictates the run-time. As one attempts to simulate lower-threshold IR physics, the computational cost increases exponentially. The number of low energy particles proliferates and one encounters many compton scatters.  10 MeV allows for reasonable simulation speed.
#
# Pre-loaded materials are lead and graphite, but other materials can be included straightforwardly running other scripts in the PETITE utilities folder

# %% [markdown]
# ## Accept/reject in PETITE
# PETITE usese VEGAS intergrator objects pre-trained on a grid of incident particle energies. During a shower the nearest energy with "good coverage" is used to draw samples, and accept reject is performed with the diffential cross section at the true physical energy.
#
# As an illustration we set an incident electron energy at $E_{e} = 1.0 ~{\rm GeV}$, and sample from several integrators trained at nearby energies for the bremsstrahlung process $e Z \rightarrow e Z \gamma$.

# %%
number_of_samples = 10000
energy_in = 100

xs0 = []
trials0 = []
for k in tqdm(range(int(number_of_samples))):
    s0 = sGraphite.draw_sample(energy_in, LU_Key=45, process='Brem', VB=True)
    xs0.append(s0[0])
    trials0.append(s0[-1])

xs1 = []
trials1 = []
for k in tqdm(range(int(number_of_samples))):
    s0 = sGraphite.draw_sample(energy_in, LU_Key=48, process='Brem', VB=True)
    xs1.append(s0[0])
    trials1.append(s0[-1])

xs2 = []
trials2 = []
for k in tqdm(range(int(number_of_samples))):
    s0 = sGraphite.draw_sample(energy_in, LU_Key=51, process='Brem', VB=True)
    xs2.append(s0[0])
    trials2.append(s0[-1])

xs3 = []
trials3 = []
for k in tqdm(range(int(number_of_samples))):
    s0 = sGraphite.draw_sample(energy_in, process='Brem', LU_Key=-1, VB=True)
    xs3.append(s0[0])
    trials3.append(s0[-1])
# Out:
#   0%|          | 0/10000 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-159c40feee3d> in <module>
#       5 trials0 = []
#       6 for k in tqdm(range(int(number_of_samples))):
# ----> 7     s0 = sGraphite.draw_sample(energy_in, LU_Key=45, process='Brem', VB=True)
#       8     xs0.append(s0[0])
#       9     trials0.append(s0[-1])
#
# NameError: name 'sGraphite' is not defined

# %% [markdown]
# ### Compare efficiency of sampling for different nearby energies

# %%
bin_space = np.linspace(0, 180, 181)
plt.hist(trials0, bins=bin_space, histtype='step', lw=1, label='LU=45')
plt.hist(trials1, bins=bin_space, histtype='step', lw=1, label='LU=48')
plt.hist(trials2, bins=bin_space, histtype='step', lw=1, label='LU=51')
plt.hist(trials3, bins=bin_space, histtype='step', lw=1, label='LU=-1')
plt.gca().set_xlabel(r"$N_{\rm draw}$")
plt.gca().set_ylabel(r"$\mathrm{Occurrence}$")
plt.gca().set_yscale('log')
# show labels
plt.legend()
# print number of trials
print("Number of trials: ", len(trials0), len(trials1), len(trials2), len(trials3))
# Out:
# Number of trials:  10000 10000 10000 10000

# %% [markdown]
# ### Check distributions to see if they are insensitive to choice of integrator object

# %%
plt.hist(xs0, bins=np.linspace(0, 1, 101), histtype='step', lw=1)
plt.hist(xs1, bins=np.linspace(0, 1, 101), histtype='step', lw=1)
plt.hist(xs2, bins=np.linspace(0, 1, 101), histtype='step', lw=1)
plt.hist(xs3, bins=np.linspace(0, 1, 101), histtype='step', lw=1)
plt.gca().set_xlabel(r"$x_1\ (E_{\gamma}\ \rm{proxy})$")
plt.gca().set_ylabel(r"$\mathrm{Occurrence}$")
plt.gca().set_yscale('log')

# %% [markdown]
# ## Use of rotated coordinates

# %% [markdown]
# PETITE uses small angle variables (see e.g. sections 92-94 of Landau and Lifshitz Vol 4). However low-momentum transfers occur along a correlated "ridge" in these variables. To improve performance we have rotated angles.
#
# We illustrate the difference in performance, and benchmark total cross sections computed using the VEGAS integrators below.

# %%
xsec_dicts = pk.load(open(PETITE_home_dir+dictionary_dir+"sm_xsec.pkl", "rb"))

# %% [markdown]
# ### Pair production
#
# Cross sections are material dependent due to $Z^2$ scaling, but also due to atomic form factors (see e.g.\ Tsai Rev. Mod. Phys. (1974).

# %%
plt.plot(np.transpose(xsec_dicts['PairProd']['graphite'])[0], np.transpose(xsec_dicts['PairProd']['graphite'])[1]/6**2, color='dodgerblue', ls='-.', label=r"$\mathrm{Rotated/dimensionless,\ graphite,\ }n_{\rm eval}=300$")
plt.plot(np.transpose(xsec_dicts['PairProd']['lead'])[0], np.transpose(xsec_dicts['PairProd']['lead'])[1]/82**2, color='coral', ls='-.', label=r"$\mathrm{Rotated/dimensionless,\ lead,\ }n_{\rm eval}=300$")

plt.legend(loc='best')

plt.gca().set_xlabel(r"$E_{\gamma}\ [\mathrm{GeV}]$")
plt.gca().set_ylabel(r"$\sigma_{\rm pair\ prod.}/Z^2\ [\mathrm{GeV^{-2}}]$")

plt.gca().set_xscale('log')
plt.gca().set_yscale('log')

# %% [markdown]
# ### Bremsstrahlung

# %%
plt.plot(np.transpose(xsec_dicts['Brem']['graphite'])[0], np.transpose(xsec_dicts['Brem']['graphite'])[1]/6**2, color='dodgerblue', ls='-.', label=r"$\mathrm{Rotated/dimensionless,\ graphite,\ }n_{\rm eval}=300$")
plt.plot(np.transpose(xsec_dicts['Brem']['lead'])[0], np.transpose(xsec_dicts['Brem']['lead'])[1]/82**2, color='coral', ls='-.', label=r"$\mathrm{Rotated/dimensionless,\ lead,\ }n_{\rm eval}=300$")

plt.legend(loc='best')

plt.gca().set_xlabel(r"$E_{e}\ [\mathrm{GeV}]$")
plt.gca().set_ylabel(r"$\sigma_{\rm brem.}/Z^2\ [\mathrm{GeV^{-2}}]$")

plt.gca().set_xscale('log')
plt.gca().set_yscale('log')

# %%
plt.plot(np.transpose(xsec_dicts['Bhabha']['graphite'])[0], np.transpose(xsec_dicts['Bhabha']['graphite'])[1], color='dodgerblue', ls='-.', label=r"$\mathrm{Bhabha}$")
plt.plot(np.transpose(xsec_dicts['Moller']['graphite'])[0], np.transpose(xsec_dicts['Moller']['graphite'])[1], color='coral', ls='-.', label=r"$\mathrm{Moller}$")

plt.legend(loc='best')

plt.gca().set_xlabel(r"$E_{e}\ [\mathrm{GeV}]$")
plt.gca().set_ylabel(r"$\sigma\ [\mathrm{GeV^{-2}}]$")

plt.gca().set_xscale('log')
plt.gca().set_yscale('log')

# %%
plt.plot(np.transpose(xsec_dicts['Brem']['graphite'])[0], np.transpose(xsec_dicts['Brem']['graphite'])[1], color='dodgerblue', ls='-', label=r"$\mathrm{Brem.}$")
plt.plot(np.transpose(xsec_dicts['Moller']['graphite'])[0], np.transpose(xsec_dicts['Moller']['graphite'])[1]*6, color='coral', ls='-', label=r"$\mathrm{Moller}\times 6$")

plt.legend(loc='best')

plt.gca().set_xlabel(r"$E_{e}\ [\mathrm{GeV}]$")
plt.gca().set_ylabel(r"$\sigma\ [\mathrm{GeV^{-2}}]$")

plt.gca().set_xscale('log')
plt.gca().set_yscale('log')

# %% [markdown]
# ## Ensemble shower production with PETITE
#
# Expanding on the above, we can produce many showers produced by the same incident particle and analyze statistics of shower ensembles. The flexibility and speed of PETITE is a priority in this context, and so we first explore the timing of shower generation.

# %% [markdown]
# Check shower timing

# %%
def slowShower():
    s0 = sGraphite.generate_shower(p0, VB=True)
    return

# %% [markdown]
# We use the package cProfile to return useful information on the runtime. This is helpful if one would like to change $E_{\rm min}$ which can slow down the code. The output below is helpful in diagnosing bottlenecks etc.

# %%
profileSS = cProfile.Profile()
profileSS.runcall(slowShower)
psSS = pstats.Stats(profileSS)
psSS.print_stats()
# Out:
# Starting shower, initial particle with ID Info
# {'PID': 11, 'ID': 0, 'parent_PID': 22, 'parent_ID': -1, 'generation_number': 0, 'generation_process': 'Input', 'weight': 1.0, 'mass': 0.000511, 'stability': 'stable'}
# Initial four-momenta:
# [10.          0.          0.          9.99999999]
#          2340059 function calls (2326316 primitive calls) in 2.721 seconds
#
#    Random listing order was used
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.000    0.000 {method 'acquire' of '_thread.lock' objects}
#         8    0.000    0.000    0.000    0.000 {method '__exit__' of '_thread.RLock' objects}
#         1    0.000    0.000    0.000    0.000 {built-in method _thread.get_ident}
#         8    0.000    0.000    0.000    0.000 {method 'write' of '_io.StringIO' objects}
#         1    0.000    0.000    0.000    0.000 {method 'append' of 'collections.deque' objects}
#         8    0.000    0.000    0.000    0.000 {built-in method posix.getpid}
#       720    0.001    0.000    0.001    0.000 {built-in method builtins.all}
#      8140    0.005    0.000    0.005    0.000 {built-in method builtins.getattr}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.hasattr}
#        46    0.000    0.000    0.000    0.000 {built-in method builtins.id}
#     25866    0.005    0.000    0.005    0.000 {built-in method builtins.isinstance}
#     90195    0.015    0.000    0.015    0.000 {built-in method builtins.issubclass}
#    118008    0.013    0.000    0.013    0.000 {built-in method builtins.len}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.locals}
#         3    0.000    0.000    0.000    0.000 {built-in method builtins.max}
#         4    0.000    0.000    0.001    0.000 {built-in method builtins.print}
#      2128    0.015    0.000    0.015    0.000 {built-in method builtins.round}
#         4    0.000    0.000    0.000    0.000 {method 'split' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 {method 'rstrip' of 'str' objects}
#         4    0.000    0.000    0.000    0.000 {method 'splitlines' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 {method '__reduce_ex__' of 'object' objects}
#         1    0.000    0.000    0.000    0.000 {built-in method __new__ of type object at 0x564e316f2f20}
#         1    0.000    0.000    0.000    0.000 {method 'add' of 'set' objects}
#         1    0.000    0.000    0.000    0.000 {method 'discard' of 'set' objects}
#      1490    0.000    0.000    0.000    0.000 {method 'get' of 'dict' objects}
#     10892    0.001    0.000    0.001    0.000 {method 'keys' of 'dict' objects}
#      4350    0.001    0.000    0.001    0.000 {method 'items' of 'dict' objects}
#         2    0.000    0.000    0.000    0.000 {method 'update' of 'dict' objects}
#       533    0.000    0.000    0.000    0.000 {method 'copy' of 'dict' objects}
#      4322    0.001    0.000    0.001    0.000 {method 'bit_length' of 'int' objects}
#     48829    0.006    0.000    0.006    0.000 {method 'append' of 'list' objects}
#      35/1    0.000    0.000    0.000    0.000 /home/nblinov/miniconda3/envs/petite/lib/python3.11/copy.py:128(deepcopy)
#         1    0.000    0.000    0.000    0.000 /home/nblinov/miniconda3/envs/petite/lib/python3.11/copy.py:259(_reconstruct)
#         1    0.000    0.000    0.000    0.000 /home/nblinov/miniconda3/envs/petite/lib/python3.11/site-packages/zmq/sugar/socket.py:613(send)
#         8    0.000    0.000    0.000    0.000 /home/nblinov/miniconda3/envs/petite/lib/python3.11/site-packages/ipykernel/iostream.py:535(write)
#         1    0.000    0.000    0.000    0.000 /home/nblinov/miniconda3/envs/petite/lib/python3.11/site-packages/numpy/core/arrayprint.py:64(_make_options_dict)
#         1    0.000    0.000    0.001    0.001 /home/nblinov/miniconda3/envs/petite/lib/python3.11/site-packages/numpy/core/arrayprint.py:561(array2string)
#         2    0.000    0.000    0.000    0.000 /home/nblinov/miniconda3/envs/petite/lib/python3.11/site-packages/numpy/core/_ufunc_config.py:33(seterr)
#         4    0.000    0.000    0.000    0.000 /home/nblinov/miniconda3/envs/petite/lib/python3.11/site-packages/numpy/core/arrayprint.py:753(_extendLine_pretty)
#         4    0.000    0.000    0.000    0.000 /home/nblinov/miniconda3/envs/petite/lib/python3.11/site-packages/numpy/core/arrayprint.py:1018(__call__)
#         1    0.000    0.000    0.000    0.000 /home/nblinov/miniconda3/envs/petite/lib/python3.11/site-packages/numpy/core/arrayprint.py:403(_get_formatdict)
#         1    0.000    0.000    0.000    0.000 /home/nblinov/miniconda3/envs/petite/lib/python3.11/site-packages/numpy/core/arrayprint.py:452(_get_format_function)
#       5/1    0.000    0.000    0.000    0.000 /home/nblinov/miniconda3/envs/petite/lib/python3.11/site-packages/numpy/core/arrayprint.py:789(recurser)
#         1    0.000    0.000    0.000    0.000 /home/nblinov/miniconda3/envs/petite/lib/python3.11/site-packages/numpy/core/arrayprint.py:907(__init__)
#         1    0.000    0.000    0.000    0.000 /home/nblinov/miniconda3/envs/petite/lib/python3.11/site-packages/numpy/core/arrayprint.py:934(fillFormat)
#      1422    0.002    0.000    0.002    0.000 /home/nblinov/miniconda3/envs/petite/lib/python3.11/site-packages/numpy/core/getlimits.py:476(__new__)
#     18889    0.058    0.000    0.106    0.000 /home/nblinov/miniconda3/envs/petite/lib/python3.11/site-packages/numpy/linalg/linalg.py:2342(norm)
#     12569    0.017    0.000    0.058    0.000 /home/nblinov/miniconda3/envs/petite/lib/python3.11/site-packages/numpy/lib/function_base.py:1457(interp)
#       532    0.131    0.000    1.487    0.003 /home/nblinov/miniconda3/envs/petite/lib/python3.11/site-packages/PETITE/shower.py:290(draw_sample)
#       711    0.035    0.000    1.606    0.002 /home/nblinov/miniconda3/envs/petite/lib/python3.11/site-packages/PETITE/shower.py:356(sample_scattering)
#      4690    0.025    0.000    0.310    0.000 /home/nblinov/miniconda3/envs/petite/lib/python3.11/site-packages/PETITE/shower.py:266(get_mfp)
#       718    0.065    0.000    0.926    0.001 /home/nblinov/miniconda3/envs/petite/lib/python3.11/site-packages/PETITE/shower.py:395(propagate_particle)
#         1    0.020    0.020    2.721    2.721 /home/nblinov/miniconda3/envs/petite/lib/python3.11/site-packages/PETITE/shower.py:489(generate_shower)
#     12569    0.049    0.000    0.049    0.000 /home/nblinov/miniconda3/envs/petite/lib/python3.11/site-packages/scipy/interpolate/_interpolate.py:760(_check_bounds)
#     12569    0.045    0.000    0.103    0.000 /home/nblinov/miniconda3/envs/petite/lib/python3.11/site-packages/scipy/_lib/_util.py:206(_asarray_validated)
#     12569    0.010    0.000    0.016    0.000 /home/nblinov/miniconda3/envs/petite/lib/python3.11/site-packages/scipy/interpolate/_polyint.py:95(_finish_y)
#      4322    0.032    0.000    0.074    0.000 /home/nblinov/miniconda3/envs/petite/lib/python3.11/site-packages/PETITE/particle.py:116(lose_energy)
#      1064    0.005    0.000    0.033    0.000 /home/nblinov/miniconda3/envs/petite/lib/python3.11/site-packages/PETITE/particle.py:29(__init__)
#       532    0.011    0.000    0.011    0.000 /home/nblinov/miniconda3/envs/petite/lib/python3.11/site-packages/PETITE/particle.py:147(rotation_matrix)
#       337    0.009    0.000    0.011    0.000 /home/nblinov/miniconda3/envs/petite/lib/python3.11/site-packages/PETITE/kinematics.py:10(e_to_egamma_fourvecs)
#      4322    0.032    0.000    0.113    0.000 /home/nblinov/miniconda3/envs/petite/lib/python3.11/site-packages/PETITE/moliere.py:265(generate_moliere_angle_simplified_alt)
#      4322    0.088    0.000    0.387    0.000 /home/nblinov/miniconda3/envs/petite/lib/python3.11/site-packages/PETITE/moliere.py:350(get_scattered_momentum_fast)
#      4322    0.082    0.000    0.096    0.000 /home/nblinov/miniconda3/envs/petite/lib/python3.11/site-packages/PETITE/moliere.py:287(get_rotation_matrix)
#        18    0.000    0.000    0.000    0.000 /home/nblinov/miniconda3/envs/petite/lib/python3.11/site-packages/PETITE/all_processes.py:502(dsigma_bhabha_dCT)
#      4299    0.057    0.000    0.083    0.000 /home/nblinov/miniconda3/envs/petite/lib/python3.11/site-packages/PETITE/all_processes.py:368(dsigma_pairprod_dimensionless)
#        95    0.002    0.000    0.003    0.000 /home/nblinov/miniconda3/envs/petite/lib/python3.11/site-packages/PETITE/kinematics.py:68(gamma_to_epem_fourvecs)
#        70    0.002    0.000    0.002    0.000 /home/nblinov/miniconda3/envs/petite/lib/python3.11/site-packages/PETITE/kinematics.py:102(compton_fourvecs)
#        77    0.001    0.000    0.001    0.000 /home/nblinov/miniconda3/envs/petite/lib/python3.11/site-packages/PETITE/all_processes.py:460(dsigma_moller_dCT)
#        23    0.001    0.000    0.001    0.000 /home/nblinov/miniconda3/envs/petite/lib/python3.11/site-packages/PETITE/kinematics.py:132(ee_to_ee_fourvecs)
#         7    0.000    0.000    0.000    0.000 /home/nblinov/miniconda3/envs/petite/lib/python3.11/site-packages/PETITE/kinematics.py:191(annihilation_fourvecs)
#        71    0.002    0.000    0.003    0.000 /home/nblinov/miniconda3/envs/petite/lib/python3.11/site-packages/PETITE/all_processes.py:409(dsigma_compton_dCT)
#     43599    0.651    0.000    0.911    0.000 /home/nblinov/miniconda3/envs/petite/lib/python3.11/site-packages/PETITE/all_processes.py:112(dsigma_brem_dimensionless)
#        43    0.001    0.000    0.001    0.000 /home/nblinov/miniconda3/envs/petite/lib/python3.11/site-packages/PETITE/all_processes.py:323(dsigma_annihilation_dCT)
#       532    0.000    0.000    0.000    0.000 src/vegas/_vegas.pxd:54(__set__)
#       532    0.000    0.000    0.000    0.000 src/vegas/_vegas.pxd:54(__get__)
#       532    0.000    0.000    0.000    0.000 src/vegas/_vegas.pxd:55(__get__)
#       532    0.000    0.000    0.000    0.000 src/vegas/_vegas.pxd:55(__set__)
#       532    0.000    0.000    0.000    0.000 src/vegas/_vegas.pxd:52(__get__)
#       532    0.000    0.000    0.000    0.000 src/vegas/_vegas.pxd:47(__set__)
#       532    0.000    0.000    0.000    0.000 src/vegas/_vegas.pxd:49(__set__)
#       532    0.000    0.000    0.000    0.000 src/vegas/_vegas.pxd:46(__set__)
#       532    0.000    0.000    0.000    0.000 src/vegas/_vegas.pxd:49(__get__)
#       532    0.000    0.000    0.000    0.000 src/vegas/_vegas.pxd:47(__get__)
#       532    0.000    0.000    0.000    0.000 src/vegas/_vegas.pxd:45(__set__)
#       532    0.000    0.000    0.000    0.000 src/vegas/_vegas.pxd:46(__get__)
#       532    0.000    0.000    0.000    0.000 src/vegas/_vegas.pxd:52(__set__)
#       532    0.000    0.000    0.000    0.000 src/vegas/_vegas.pxd:53(__get__)
#       532    0.000    0.000    0.000    0.000 src/vegas/_vegas.pxd:53(__set__)
#       532    0.000    0.000    0.000    0.000 src/vegas/_vegas.pxd:60(__get__)
#       532    0.000    0.000    0.000    0.000 src/vegas/_vegas.pxd:60(__set__)
#       532    0.000    0.000    0.000    0.000 src/vegas/_vegas.pxd:50(__get__)
#       532    0.000    0.000    0.000    0.000 src/vegas/_vegas.pxd:50(__set__)
#       532    0.000    0.000    0.000    0.000 src/vegas/_vegas.pxd:51(__get__)
#       532    0.000    0.000    0.000    0.000 src/vegas/_vegas.pxd:51(__set__)
#       532    0.000    0.000    0.000    0.000 src/vegas/_vegas.pxd:56(__get__)
#       532    0.000    0.000    0.000    0.000 src/vegas/_vegas.pxd:56(__set__)
#       532    0.000    0.000    0.000    0.000 src/vegas/_vegas.pxd:57(__get__)
#       532    0.000    0.000    0.000    0.000 src/vegas/_vegas.pxd:57(__set__)
#       532    0.000    0.000    0.000    0.000 src/vegas/_vegas.pxd:58(__get__)
#       532    0.000    0.000    0.000    0.000 src/vegas/_vegas.pxd:58(__set__)
#       532    0.000    0.000    0.000    0.000 src/vegas/_vegas.pxd:59(__get__)
#       532    0.000    0.000    0.000    0.000 src/vegas/_vegas.pxd:59(__set__)
#       532    0.000    0.000    0.000    0.000 src/vegas/_vegas.pxd:61(__get__)
#       532    0.000    0.000    0.000    0.000 src/vegas/_vegas.pxd:61(__set__)
#      9440    0.007    0.000    0.016    0.000 stringsource:405(__getitem__)
#      9440    0.002    0.000    0.002    0.000 stringsource:668(_unellipsify)
#      9440    0.003    0.000    0.006    0.000 stringsource:395(get_item_pointer)
#      9440    0.003    0.000    0.003    0.000 stringsource:912(pybuffer_index)
#      7312    0.001    0.000    0.001    0.000 stringsource:981(convert_item_to_object)
#         1    0.000    0.000    2.721    2.721 /tmp/ipykernel_14774/143096223.py:1(slowShower)
#       532    0.000    0.000    0.000    0.000 stringsource:607(__len__)
#     48107    0.009    0.000    0.009    0.000 stringsource:565(__get__)
#       532    0.000    0.000    0.000    0.000 src/vegas/_vegas.pxd:39(__set__)
#       532    0.000    0.000    0.000    0.000 src/vegas/_vegas.pxd:43(__get__)
#       532    0.000    0.000    0.000    0.000 src/vegas/_vegas.pxd:42(__get__)
#     55768    0.006    0.000    0.006    0.000 stringsource:978(__dealloc__)
#       532    0.000    0.000    0.000    0.000 src/vegas/_vegas.pxd:43(__set__)
#       532    0.000    0.000    0.000    0.000 src/vegas/_vegas.pxd:44(__get__)
#       532    0.000    0.000    0.000    0.000 src/vegas/_vegas.pxd:45(__get__)
#       532    0.000    0.000    0.000    0.000 src/vegas/_vegas.pxd:44(__set__)
#      1064    0.000    0.000    0.000    0.000 src/vegas/_vegas.pyx:142(__get__)
#       532    0.000    0.000    0.000    0.000 src/vegas/_vegas.pxd:41(__get__)
#       532    0.000    0.000    0.000    0.000 src/vegas/_vegas.pxd:42(__set__)
#       532    0.000    0.000    0.001    0.000 src/vegas/_vegas.pxd:27(__get__)
#       532    0.000    0.000    0.000    0.000 src/vegas/_vegas.pxd:41(__set__)
#       532    0.000    0.000    0.000    0.000 src/vegas/_vegas.pxd:39(__get__)
#     55768    0.044    0.000    0.054    0.000 stringsource:1001(memoryview_fromslice)
#     67827    0.006    0.000    0.006    0.000 stringsource:374(__dealloc__)
#       532    0.000    0.000    0.001    0.000 src/vegas/_vegas.pxd:28(__get__)
#     55768    0.005    0.000    0.005    0.000 stringsource:561(__get__)
#       532    0.014    0.000    0.019    0.000 src/vegas/_vegas.pyx:113(__init__)
#     54172    0.005    0.000    0.005    0.000 stringsource:520(__getbuffer__)
#     67827    0.008    0.000    0.008    0.000 stringsource:346(__cinit__)
#       532    0.000    0.000    0.001    0.000 src/vegas/_vegas.pxd:29(__get__)
#     12059    0.008    0.000    0.011    0.000 stringsource:659(memoryview_cwrapper)
#       532    0.006    0.000    0.169    0.000 src/vegas/_vegas.pyx:1113(__init__)
#     12059    0.001    0.000    0.001    0.000 stringsource:665(memoryview_check)
#     21738    0.003    0.000    0.003    0.000 /home/nblinov/miniconda3/envs/petite/lib/python3.11/site-packages/PETITE/particle.py:80(get_ids)
#      1064    0.000    0.000    0.000    0.000 /home/nblinov/miniconda3/envs/petite/lib/python3.11/site-packages/PETITE/particle.py:96(set_mass)
#      2667    0.001    0.000    0.001    0.000 /home/nblinov/miniconda3/envs/petite/lib/python3.11/site-packages/PETITE/particle.py:105(get_p0)
#      9697    0.003    0.000    0.003    0.000 /home/nblinov/miniconda3/envs/petite/lib/python3.11/site-packages/PETITE/particle.py:107(set_pf)
#     26091    0.004    0.000    0.004    0.000 /home/nblinov/miniconda3/envs/petite/lib/python3.11/site-packages/PETITE/particle.py:109(get_pf)
#      1064    0.000    0.000    0.000    0.000 /home/nblinov/miniconda3/envs/petite/lib/python3.11/site-packages/PETITE/particle.py:126(set_r0)
#       883    0.000    0.000    0.000    0.000 /home/nblinov/miniconda3/envs/petite/lib/python3.11/site-packages/PETITE/particle.py:128(get_r0)
#      5551    0.001    0.000    0.001    0.000 /home/nblinov/miniconda3/envs/petite/lib/python3.11/site-packages/PETITE/particle.py:130(set_rf)
#      6104    0.001    0.000    0.001    0.000 /home/nblinov/miniconda3/envs/petite/lib/python3.11/site-packages/PETITE/particle.py:132(get_rf)
#    275201    0.027    0.000    0.027    0.000 /home/nblinov/miniconda3/envs/petite/lib/python3.11/site-packages/PETITE/particle.py:141(get_ended)
#     39927    0.013    0.000    0.013    0.000 /home/nblinov/miniconda3/envs/petite/lib/python3.11/site-packages/PETITE/all_processes.py:70(aa)
#      4322    0.019    0.000    0.019    0.000 /home/nblinov/miniconda3/envs/petite/lib/python3.11/site-packages/PETITE/moliere.py:196(get_chic_squared_alt)
#      1064    0.005    0.000    0.006    0.000 /home/nblinov/miniconda3/envs/petite/lib/python3.11/site-packages/PETITE/particle.py:73(set_ids)
#      4322    0.027    0.000    0.027    0.000 /home/nblinov/miniconda3/envs/petite/lib/python3.11/site-packages/PETITE/moliere.py:209(get_chia_squared_alt)
#     12569    0.020    0.000    0.327    0.000 /home/nblinov/miniconda3/envs/petite/lib/python3.11/site-packages/scipy/interpolate/_polyint.py:58(__call__)
#     39927    0.050    0.000    0.063    0.000 /home/nblinov/miniconda3/envs/petite/lib/python3.11/site-packages/PETITE/all_processes.py:77(g2_elastic)
#      1783    0.001    0.000    0.001    0.000 /home/nblinov/miniconda3/envs/petite/lib/python3.11/site-packages/PETITE/particle.py:135(set_ended)
#       603    0.007    0.000    0.007    0.000 src/vegas/_vegas.pyx:310(map)
#       532    0.018    0.000    0.041    0.000 src/vegas/_vegas.pyx:467(adapt)
#      1064    0.000    0.000    0.000    0.000 src/vegas/_vegas.pyx:596(clear)
#       532    0.068    0.000    0.138    0.000 src/vegas/_vegas.pyx:1162(set)
#      1206    0.026    0.000    0.050    0.000 src/vegas/_vegas.pyx:1471(random_batch)
#     48710    0.021    0.000    0.120    0.000 src/vegas/_vegas.pyx:1612(random)
#     12569    0.014    0.000    0.120    0.000 /home/nblinov/miniconda3/envs/petite/lib/python3.11/site-packages/scipy/interpolate/_polyint.py:89(_prepare_x)
#      1064    0.004    0.000    0.019    0.000 /home/nblinov/miniconda3/envs/petite/lib/python3.11/site-packages/PETITE/particle.py:98(set_p0)
#     12569    0.006    0.000    0.009    0.000 /home/nblinov/miniconda3/envs/petite/lib/python3.11/site-packages/scipy/sparse/_base.py:1301(isspmatrix)
#         2    0.000    0.000    0.000    0.000 {method '__deepcopy__' of 'numpy.ndarray' objects}
#       532    0.001    0.000    0.001    0.000 {method 'argmin' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.000    0.000 {method 'astype' of 'numpy.ndarray' objects}
#     18889    0.019    0.000    0.019    0.000 {method 'dot' of 'numpy.ndarray' objects}
#     31458    0.009    0.000    0.009    0.000 {method 'ravel' of 'numpy.ndarray' objects}
#     12569    0.006    0.000    0.006    0.000 {method 'reshape' of 'numpy.ndarray' objects}
#      4322    0.002    0.000    0.002    0.000 {method 'transpose' of 'numpy.ndarray' objects}
#     71313    0.114    0.000    0.119    0.000 {built-in method numpy.array}
#     56597    0.022    0.000    0.022    0.000 {built-in method numpy.asarray}
#      4322    0.002    0.000    0.002    0.000 {built-in method numpy.zeros}
#      1064    0.001    0.000    0.001    0.000 {built-in method numpy.empty}
#         8    0.000    0.000    0.000    0.000 {built-in method numpy.core._multiarray_umath.dragon4_positional}
# 106726/93022    0.100    0.000    0.359    0.000 {built-in method numpy.core._multiarray_umath.implement_array_function}
#     12569    0.013    0.000    0.013    0.000 {built-in method numpy.core._multiarray_umath.interp}
#         2    0.000    0.000    0.000    0.000 {built-in method numpy.seterrobj}
#         4    0.000    0.000    0.000    0.000 {built-in method numpy.geterrobj}
#         1    0.000    0.000    0.000    0.000 {method '__deepcopy__' of 'numpy.generic' objects}
#      4347    0.023    0.000    0.024    0.000 {method 'reduce' of 'numpy.ufunc' objects}
#     48107    0.034    0.000    0.034    0.000 {method 'random' of 'numpy.random.mtrand.RandomState' objects}
#       711    0.025    0.000    0.029    0.000 {method 'choice' of 'numpy.random.mtrand.RandomState' objects}
#      9544    0.032    0.000    0.032    0.000 {method 'uniform' of 'numpy.random.mtrand.RandomState' objects}
#       532    0.009    0.000    0.009    0.000 /home/nblinov/miniconda3/envs/petite/lib/python3.11/site-packages/PETITE/shower.py:307(<listcomp>)
#     12569    0.005    0.000    0.007    0.000 /home/nblinov/miniconda3/envs/petite/lib/python3.11/site-packages/numpy/ma/core.py:6450(isMaskedArray)
#         2    0.000    0.000    0.000    0.000 /home/nblinov/miniconda3/envs/petite/lib/python3.11/site-packages/PETITE/shower.py:520(<listcomp>)
#       718    0.054    0.000    0.080    0.000 /home/nblinov/miniconda3/envs/petite/lib/python3.11/site-packages/PETITE/shower.py:540(<listcomp>)
#     12569    0.010    0.000    0.088    0.000 /home/nblinov/miniconda3/envs/petite/lib/python3.11/site-packages/scipy/interpolate/_interpolate.py:672(_call_linear_np)
#     12569    0.029    0.000    0.170    0.000 /home/nblinov/miniconda3/envs/petite/lib/python3.11/site-packages/scipy/interpolate/_interpolate.py:745(_evaluate)
#     12569    0.011    0.000    0.079    0.000 <__array_function__ internals>:177(interp)
#       532    0.001    0.000    0.004    0.000 <__array_function__ internals>:177(argmin)
#     48639    0.034    0.000    0.123    0.000 <__array_function__ internals>:177(shape)
#       717    0.001    0.000    0.012    0.000 <__array_function__ internals>:177(sum)
#      1064    0.001    0.000    0.012    0.000 <__array_function__ internals>:177(all)
#      1430    0.002    0.000    0.021    0.000 <__array_function__ internals>:177(amax)
#         1    0.000    0.000    0.000    0.000 <__array_function__ internals>:177(amin)
#      1135    0.001    0.000    0.018    0.000 <__array_function__ internals>:177(prod)
#      1135    0.001    0.000    0.022    0.000 <__array_function__ internals>:177(product)
#         1    0.000    0.000    0.001    0.001 /home/nblinov/miniconda3/envs/petite/lib/python3.11/site-packages/numpy/core/arrayprint.py:523(_array2string)
#     12569    0.002    0.000    0.002    0.000 /home/nblinov/miniconda3/envs/petite/lib/python3.11/site-packages/numpy/lib/type_check.py:206(_is_type_dispatcher)
#     18889    0.003    0.000    0.003    0.000 /home/nblinov/miniconda3/envs/petite/lib/python3.11/site-packages/numpy/linalg/linalg.py:2338(_norm_dispatcher)
#     18889    0.006    0.000    0.008    0.000 /home/nblinov/miniconda3/envs/petite/lib/python3.11/site-packages/numpy/linalg/linalg.py:117(isComplexType)
#     12569    0.008    0.000    0.026    0.000 <__array_function__ internals>:177(iscomplexobj)
#     12569    0.002    0.000    0.002    0.000 /home/nblinov/miniconda3/envs/petite/lib/python3.11/site-packages/numpy/lib/function_base.py:1453(_interp_dispatcher)
#     18889    0.014    0.000    0.135    0.000 <__array_function__ internals>:177(norm)
#      1596    0.000    0.000    0.000    0.000 /home/nblinov/miniconda3/envs/petite/lib/python3.11/site-packages/numpy/core/multiarray.py:152(concatenate)
#       532    0.001    0.000    0.003    0.000 /home/nblinov/miniconda3/envs/petite/lib/python3.11/site-packages/numpy/core/fromnumeric.py:1249(argmin)
#         1    0.000    0.000    0.000    0.000 /home/nblinov/miniconda3/envs/petite/lib/python3.11/site-packages/numpy/core/arrayprint.py:780(_formatArray)
#      1064    0.000    0.000    0.000    0.000 /home/nblinov/miniconda3/envs/petite/lib/python3.11/site-packages/numpy/core/multiarray.py:740(dot)
#      1064    0.000    0.000    0.000    0.000 /home/nblinov/miniconda3/envs/petite/lib/python3.11/site-packages/numpy/core/multiarray.py:1079(copyto)
#       532    0.000    0.000    0.000    0.000 /home/nblinov/miniconda3/envs/petite/lib/python3.11/site-packages/numpy/core/fromnumeric.py:1245(_argmin_dispatcher)
#       717    0.000    0.000    0.000    0.000 /home/nblinov/miniconda3/envs/petite/lib/python3.11/site-packages/numpy/core/fromnumeric.py:2183(_sum_dispatcher)
#      1064    0.000    0.000    0.000    0.000 /home/nblinov/miniconda3/envs/petite/lib/python3.11/site-packages/numpy/core/fromnumeric.py:2427(_all_dispatcher)
#      1430    0.000    0.000    0.000    0.000 /home/nblinov/miniconda3/envs/petite/lib/python3.11/site-packages/numpy/core/fromnumeric.py:2698(_amax_dispatcher)
#         1    0.000    0.000    0.000    0.000 /home/nblinov/miniconda3/envs/petite/lib/python3.11/site-packages/numpy/core/fromnumeric.py:2824(_amin_dispatcher)
#      2270    0.000    0.000    0.000    0.000 /home/nblinov/miniconda3/envs/petite/lib/python3.11/site-packages/numpy/core/fromnumeric.py:2950(_prod_dispatcher)
#     26560    0.014    0.000    0.022    0.000 /home/nblinov/miniconda3/envs/petite/lib/python3.11/site-packages/numpy/core/numerictypes.py:282(issubclass_)
#      1064    0.001    0.000    0.010    0.000 /home/nblinov/miniconda3/envs/petite/lib/python3.11/site-packages/numpy/core/fromnumeric.py:2432(all)
#      1430    0.002    0.000    0.018    0.000 /home/nblinov/miniconda3/envs/petite/lib/python3.11/site-packages/numpy/core/fromnumeric.py:2703(amax)
#         1    0.000    0.000    0.000    0.000 /home/nblinov/miniconda3/envs/petite/lib/python3.11/site-packages/numpy/core/fromnumeric.py:2829(amin)
#      1135    0.002    0.000    0.015    0.000 /home/nblinov/miniconda3/envs/petite/lib/python3.11/site-packages/numpy/core/fromnumeric.py:2955(prod)
#         5    0.000    0.000    0.000    0.000 /home/nblinov/miniconda3/envs/petite/lib/python3.11/site-packages/numpy/core/arrayprint.py:989(<genexpr>)
#      4322    0.001    0.000    0.001    0.000 /home/nblinov/miniconda3/envs/petite/lib/python3.11/site-packages/numpy/core/fromnumeric.py:597(_transpose_dispatcher)
#     48639    0.006    0.000    0.006    0.000 /home/nblinov/miniconda3/envs/petite/lib/python3.11/site-packages/numpy/core/fromnumeric.py:1987(_shape_dispatcher)
#      1064    0.001    0.000    0.007    0.000 <__array_function__ internals>:177(dot)
#      1064    0.002    0.000    0.005    0.000 <__array_function__ internals>:177(copyto)
#      4322    0.004    0.000    0.017    0.000 <__array_function__ internals>:177(transpose)
#      4322    0.003    0.000    0.010    0.000 /home/nblinov/miniconda3/envs/petite/lib/python3.11/site-packages/numpy/core/fromnumeric.py:601(transpose)
#      1135    0.001    0.000    0.018    0.000 /home/nblinov/miniconda3/envs/petite/lib/python3.11/site-packages/numpy/core/fromnumeric.py:3766(product)
#         1    0.000    0.000    0.000    0.000 /home/nblinov/miniconda3/envs/petite/lib/python3.11/site-packages/numpy/core/_ufunc_config.py:426(__init__)
#         1    0.000    0.000    0.000    0.000 /home/nblinov/miniconda3/envs/petite/lib/python3.11/site-packages/numpy/core/arrayprint.py:72(<dictcomp>)
#     48639    0.023    0.000    0.032    0.000 /home/nblinov/miniconda3/envs/petite/lib/python3.11/site-packages/numpy/core/fromnumeric.py:1991(shape)
#         1    0.000    0.000    0.000    0.000 /home/nblinov/miniconda3/envs/petite/lib/python3.11/site-packages/numpy/core/arrayprint.py:898(_none_or_positive_arg)
#         5    0.000    0.000    0.000    0.000 /home/nblinov/miniconda3/envs/petite/lib/python3.11/site-packages/numpy/core/arrayprint.py:984(<genexpr>)
#         1    0.000    0.000    0.000    0.000 /home/nblinov/miniconda3/envs/petite/lib/python3.11/site-packages/numpy/core/arrayprint.py:411(<lambda>)
#         5    0.000    0.000    0.000    0.000 /home/nblinov/miniconda3/envs/petite/lib/python3.11/site-packages/numpy/core/arrayprint.py:993(<genexpr>)
#         5    0.000    0.000    0.000    0.000 /home/nblinov/miniconda3/envs/petite/lib/python3.11/site-packages/numpy/core/arrayprint.py:994(<genexpr>)
#       717    0.001    0.000    0.011    0.000 /home/nblinov/miniconda3/envs/petite/lib/python3.11/site-packages/numpy/core/fromnumeric.py:2188(sum)
#         4    0.000    0.000    0.000    0.000 /home/nblinov/miniconda3/envs/petite/lib/python3.11/site-packages/numpy/core/arrayprint.py:739(_extendLine)
#         2    0.000    0.000    0.000    0.000 /home/nblinov/miniconda3/envs/petite/lib/python3.11/site-packages/numpy/core/_ufunc_config.py:132(geterr)
#         1    0.000    0.000    0.001    0.001 /home/nblinov/miniconda3/envs/petite/lib/python3.11/site-packages/numpy/core/arrayprint.py:1571(_array_str_implementation)
#         1    0.000    0.000    0.000    0.000 /home/nblinov/miniconda3/envs/petite/lib/python3.11/site-packages/numpy/core/_ufunc_config.py:435(__exit__)
#       553    0.000    0.000    0.000    0.000 /home/nblinov/miniconda3/envs/petite/lib/python3.11/site-packages/PETITE/shower.py:141(get_material_properties)
#      4347    0.004    0.000    0.004    0.000 /home/nblinov/miniconda3/envs/petite/lib/python3.11/site-packages/numpy/core/fromnumeric.py:70(<dictcomp>)
#      4347    0.014    0.000    0.046    0.000 /home/nblinov/miniconda3/envs/petite/lib/python3.11/site-packages/numpy/core/fromnumeric.py:69(_wrapreduction)
#     13280    0.017    0.000    0.039    0.000 /home/nblinov/miniconda3/envs/petite/lib/python3.11/site-packages/numpy/core/numerictypes.py:356(issubdtype)
#      4854    0.004    0.000    0.008    0.000 /home/nblinov/miniconda3/envs/petite/lib/python3.11/site-packages/numpy/core/fromnumeric.py:51(_wrapfunc)
#     12569    0.008    0.000    0.010    0.000 /home/nblinov/miniconda3/envs/petite/lib/python3.11/site-packages/numpy/lib/type_check.py:303(iscomplexobj)
#         1    0.000    0.000    0.001    0.001 /home/nblinov/miniconda3/envs/petite/lib/python3.11/site-packages/numpy/core/arrayprint.py:506(wrapper)
#      1596    0.002    0.000    0.008    0.000 <__array_function__ internals>:177(concatenate)
#       532    0.001    0.000    0.004    0.000 /home/nblinov/miniconda3/envs/petite/lib/python3.11/site-packages/numpy/core/numeric.py:290(full)
#       532    0.001    0.000    0.004    0.000 /home/nblinov/miniconda3/envs/petite/lib/python3.11/site-packages/numpy/core/numeric.py:150(ones)
#         1    0.000    0.000    0.000    0.000 /home/nblinov/miniconda3/envs/petite/lib/python3.11/site-packages/numpy/core/_ufunc_config.py:430(__enter__)
#         8    0.000    0.000    0.000    0.000 /home/nblinov/miniconda3/envs/petite/lib/python3.11/site-packages/ipykernel/iostream.py:465(_schedule_flush)
#         8    0.000    0.000    0.000    0.000 /home/nblinov/miniconda3/envs/petite/lib/python3.11/site-packages/ipykernel/iostream.py:444(_is_master_process)
#         1    0.000    0.000    0.000    0.000 /home/nblinov/miniconda3/envs/petite/lib/python3.11/site-packages/ipykernel/iostream.py:203(schedule)
#         1    0.000    0.000    0.000    0.000 /home/nblinov/miniconda3/envs/petite/lib/python3.11/site-packages/ipykernel/iostream.py:90(_event_pipe)
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#     12966    0.002    0.000    0.002    0.000 {method 'random' of '_random.Random' objects}
#      8592    0.001    0.000    0.001    0.000 {method 'getrandbits' of '_random.Random' objects}
#         2    0.000    0.000    0.000    0.000 /home/nblinov/miniconda3/envs/petite/lib/python3.11/copy.py:264(<genexpr>)
#        26    0.000    0.000    0.000    0.000 /home/nblinov/miniconda3/envs/petite/lib/python3.11/copy.py:182(_deepcopy_atomic)
#      4322    0.001    0.000    0.001    0.000 {built-in method math.cos}
#      8644    0.004    0.000    0.004    0.000 {built-in method math.log}
#      4322    0.001    0.000    0.001    0.000 {built-in method math.sin}
#      4322    0.001    0.000    0.001    0.000 {built-in method math.sqrt}
#         1    0.000    0.000    0.000    0.000 /home/nblinov/miniconda3/envs/petite/lib/python3.11/threading.py:568(is_set)
#      4322    0.006    0.000    0.008    0.000 /home/nblinov/miniconda3/envs/petite/lib/python3.11/random.py:235(_randbelow_with_getrandbits)
#      4322    0.003    0.000    0.003    0.000 /home/nblinov/miniconda3/envs/petite/lib/python3.11/random.py:520(uniform)
#         1    0.000    0.000    0.000    0.000 /home/nblinov/miniconda3/envs/petite/lib/python3.11/threading.py:1185(is_alive)
#         6    0.000    0.000    0.000    0.000 /home/nblinov/miniconda3/envs/petite/lib/python3.11/copy.py:243(_keep_alive)
#       2/1    0.000    0.000    0.000    0.000 /home/nblinov/miniconda3/envs/petite/lib/python3.11/copy.py:227(_deepcopy_dict)
#      4322    0.005    0.000    0.014    0.000 /home/nblinov/miniconda3/envs/petite/lib/python3.11/random.py:367(choice)
#         1    0.000    0.000    0.000    0.000 /home/nblinov/miniconda3/envs/petite/lib/python3.11/threading.py:1118(_wait_for_tstate_lock)
#      8644    0.013    0.000    0.018    0.000 /home/nblinov/miniconda3/envs/petite/lib/python3.11/random.py:565(gauss)
#         1    0.000    0.000    0.000    0.000 /home/nblinov/miniconda3/envs/petite/lib/python3.11/copyreg.py:104(__newobj__)

# %% [markdown]
# ## Tests and validations
#
# Generate some ensembles of brem./pair production samples, with 10 GeV particles injected and check basic properties of distributions

# %%
particle_dict_gamma = {'PID':22, 'ID':0, 'generation_number':0, 'generation_process':'Input'}
p0G = Particle([E0, 0, 0, E0], [0,0,0], particle_dict_gamma)

# %%
nSamp = 20000 # make this larger if you want more precision (it is slower though)...
s0 = np.array([sGraphite.sample_scattering(p0, process="Brem", VB=True) for i in tqdm(range(nSamp))])
s0G = np.array([sGraphite.sample_scattering(p0G, process="PairProd", VB=True) for i in tqdm(range(nSamp))])
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 20000/20000 [00:14<00:00, 1386.59it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 20000/20000 [00:08<00:00, 2432.45it/s]

# %%
Es = np.array([s[1].get_p0()[0] for s in s0])
EsE = np.array([s[0].get_p0()[0] for s in s0])

EsG = np.array([s[1].get_p0()[0] for s in s0G])
EsGP = np.array([s[0].get_p0()[0] for s in s0G])

# %% [markdown]
# ### Photon and electron distribution from first scatter
#
# We expect a flat photon distribution in log-space

# %%
b0 = np.logspace(-3, 1, 41)

dens = False
plt.hist(Es, bins=b0, histtype='step', lw=3, color='C6', density=dens, ls='-', label=r"$\mathrm{SM,\ Ryan\ Approach}$")
plt.hist(EsE, bins=b0, histtype='step', lw=3, color='C6', density=dens, ls='--')

plt.gca().set_xscale('log')
plt.gca().set_yscale('log')
plt.gca().set_xlabel(r"$E_\gamma\ \mathrm{or}\ E_{e^-}\ [\mathrm{GeV}]$", fontsize=18)
plt.gca().set_ylabel(r"$\mathrm{particles/bin}$", fontsize=18)
[l.set_size(14) for l in plt.gca().get_xticklabels()]
[l.set_size(14) for l in plt.gca().get_yticklabels()]

set_size(5.0, 3.0)

# %% [markdown]
# ### Look at angular distributions of outgoing particles from bremsstrahlung/pair production in terms of their $p_T/p_z$

# %%
pTpz = np.array([(s[1].get_p0()[3]/np.sqrt(s[1].get_p0()[1]**2 + s[1].get_p0()[2]**2))**(-1) for s in s0])
pTpzE = np.array([(s[0].get_p0()[3]/np.sqrt(s[0].get_p0()[1]**2 + s[0].get_p0()[2]**2))**(-1) for s in s0])

pTpzG = np.array([(s[1].get_p0()[3]/np.sqrt(s[1].get_p0()[1]**2 + s[1].get_p0()[2]**2))**(-1) for s in s0G])
pTpzGP = np.array([(s[0].get_p0()[3]/np.sqrt(s[0].get_p0()[1]**2 + s[0].get_p0()[2]**2))**(-1) for s in s0G])

# %%
pT = np.array([(1/np.sqrt(s[1].get_p0()[1]**2 + s[1].get_p0()[2]**2))**(-1) for s in s0])
pTE = np.array([(1/np.sqrt(s[0].get_p0()[1]**2 + s[0].get_p0()[2]**2))**(-1) for s in s0])

pTG = np.array([(1/np.sqrt(s[1].get_p0()[1]**2 + s[1].get_p0()[2]**2))**(-1) for s in s0G])
pTGP = np.array([(1/np.sqrt(s[0].get_p0()[1]**2 + s[0].get_p0()[2]**2))**(-1) for s in s0G])

# %%
b0 = np.logspace(-10, 2, 41)

dens = True
plt.hist(pTpz, bins=b0, histtype='step', lw=3, color='C6', density=dens, ls='-', label=r"$\gamma,\ \rm{brem.}$")
plt.hist(pTpzE, bins=b0, histtype='step', lw=3, color='C6', density=dens, ls='--', label=r"$e^{-},\ \rm{brem.}$")

plt.hist(pTpzG, bins=b0, histtype='step', lw=3, color='C4', density=dens, ls='-', label=r"$e^{-},\ \rm{pair\ prod.}$")
plt.hist(pTpzGP, bins=b0, histtype='step', lw=3, color='C4', density=dens, ls='--', label=r"$e^{+},\ \rm{pair\ prod.}$")

plt.gca().legend(loc='best', fontsize=14, framealpha=1.0)
plt.gca().set_xscale('log')
plt.gca().set_yscale('log')
plt.gca().set_xlabel(r"$p_T/p_z$", fontsize=18)
plt.gca().set_ylabel(r"$dN/d(p_T/p_z)$", fontsize=18)
#plt.gca().axis([1e-3,100,1e-11,1e-3])
[l.set_size(14) for l in plt.gca().get_xticklabels()]
[l.set_size(14) for l in plt.gca().get_yticklabels()]

set_size(5.0, 3.0)

# %%
b0 = np.logspace(-10, 2, 41)

dens = True
plt.hist(pT, bins=b0, histtype='step', lw=3, color='C6', density=dens, ls='-', label=r"$\gamma,\ \rm{brem.}$")
plt.hist(pTE, bins=b0, histtype='step', lw=3, color='C6', density=dens, ls='--', label=r"$e^{-},\ \rm{brem.}$")

plt.hist(pTG, bins=b0, histtype='step', lw=3, color='C4', density=dens, ls='-', label=r"$e^{-},\ \rm{pair\ prod.}$")
plt.hist(pTGP, bins=b0, histtype='step', lw=3, color='C4', density=dens, ls='--', label=r"$e^{+},\ \rm{pair\ prod.}$")

plt.gca().legend(loc='best', fontsize=14, framealpha=1.0)
plt.gca().set_xscale('log')
plt.gca().set_yscale('log')
plt.gca().set_xlabel(r"$p_T\ [\mathrm{GeV}]$", fontsize=18)
plt.gca().set_ylabel(r"$dN/d(p_T)$", fontsize=18)
#plt.gca().axis([1e-3,100,1e-11,1e-3])
[l.set_size(14) for l in plt.gca().get_xticklabels()]
[l.set_size(14) for l in plt.gca().get_yticklabels()]

set_size(5.0, 3.0)

# %% [markdown]
# ## Outgoing electron/positron energies coming from pair production: should be identical

# %%
b0 = np.logspace(-4, 2, 41)

dens=False 

plt.hist(EsG, bins=b0, histtype='step', lw=3, color='C6', density=dens, ls='-')
plt.hist(EsGP, bins=b0, histtype='step', lw=3, color='C6', density=dens, ls='--')

#plt.gca().legend(loc=2, fontsize=16)
plt.gca().set_xscale('log')
plt.gca().set_yscale('log')
plt.gca().set_xlabel(r"$E_{e^\pm}\ [\mathrm{GeV}]$", fontsize=18)
plt.gca().set_ylabel(r"$\mathrm{photons/bin}$", fontsize=18)
#plt.gca().axis([1e-3,100,1e-11,1e-3])
[l.set_size(14) for l in plt.gca().get_xticklabels()]
[l.set_size(14) for l in plt.gca().get_yticklabels()]

set_size(5.0, 3.0)

# %% [markdown]
# ### Event-by-event ratio of $E_{e^-}/E_{e^+}$: should be symmetric about 1.

# %%
b0 = np.logspace(-4, 4, 61)

plt.hist(EsG/EsGP, bins=b0, histtype='step', lw=3, color='C6', density=False, ls='-', label=r"$\mathrm{SM,\ Ryan\ Approach}$")

#plt.gca().legend(loc=1, fontsize=16)
plt.gca().set_xscale('log')
plt.gca().set_yscale('log')
plt.gca().set_xlabel(r"$E_{e^-}/E_{e^+}$", fontsize=18)
plt.gca().set_ylabel(r"$\mathrm{simulations}$", fontsize=18)
#plt.gca().axis([1e-3,100,1e-11,1e-3])
[l.set_size(14) for l in plt.gca().get_xticklabels()]
[l.set_size(14) for l in plt.gca().get_yticklabels()]
plt.gca().axvline(1.0, color='k', lw=1, ls='--')

set_size(5.0, 3.0)

# %% [markdown]
# ### Asymmetry of the distribution.
#
# A basic test is distributions should be symmetric under  $e^+\leftrightarrow e^-$. We expect deviations due to statistical flucutations, on the order of $1/\sqrt{N}$ where $N$ is the size of the sample.

# %%
print("Asymmetry", (len(np.where(EsG > E0/2)[0]) - len(np.where(EsG < E0/2)[0]))/len(EsG) ) 
print("Statistical Error:" , 1/np.sqrt(len(EsG)) )
# Out:
# Asymmetry -0.0071
# Statistical Error: 0.007071067811865475
