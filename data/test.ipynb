# %%
import sys
import os
current_path = os.getcwd()
PETITE_home_dir = current_path.split('data')[0]
sys.path.append(PETITE_home_dir)
# load pkl data
import pickle
import numpy as np

print(PETITE_home_dir)
# load data
with open('energy_weights_particles.pkl', 'rb') as f:
    data = pickle.load(f)
# Out:
# /Users/taozhou/Documents/GitHub/PETITE/

# %%
data[0]
# Out:
# {'DarkBrem': {11: [2.257455431745491,
#    1.0966995161290156,
#    1.663002320857389,
#    0.5188892988592625,
#    2.354509332522163,
#    1.0810095483379683,
#    2.202643841429002,
#    0.07286270108326912,
#    1.0757180453947954,
#    1.2220721963632017,
#    0.06332880850174036,
#    1.0776928921674416,
#    2.251283489482074,
#    0.04204826171691784,
#    0.10673797960777631,
#    0.7753335442915795,
#    2.2636433628307664,
#    0.047229079189099445,
#    0.0701772533692473,
#    0.4641641013189357,
#    0.4285509482545783,
#    0.03286178541361944,
#    0.041150758930217364,
#    0.0981025532447409,
#    0.5787681482246446,
#    0.3446468924427834,
#    2.179791053219443,
#    0.02641273570998376,
#    0.027927936485716984,
#    0.06277080615827176,
#    0.5341436356885799,
#    0.4217370307226142,
#    1.643860953786521,
#    0.06465042458379622,
#    0.035658186410896756,
#    0.04733226354862086,
#    0.5205413990734056,
#    0.3874103916136926,
#    2.062551764271784,
# ...
